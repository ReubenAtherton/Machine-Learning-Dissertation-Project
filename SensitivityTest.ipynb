# %%
import pandas as pd
import matplotlib.pyplot as plt 

var2 = pd.read_excel('tm-status(S=2.0).xlsx')
var4 = pd.read_excel('tm-status(S=4.0).xlsx')
var6 = pd.read_excel('tm-status(S=6.0).xlsx')
var8 = pd.read_excel('tm-status(S=8.0).xlsx')
var10 = pd.read_excel('tm-status(S=10.0).xlsx')

s2 = var2[['flips0', 'flips1', 'flips2', 'flips3', 'flips4', 'flips5', 'flips6', 'flips7', 'flips8', 'flips9']]
s4 = var4[['flips0', 'flips1', 'flips2', 'flips3', 'flips4', 'flips5', 'flips6', 'flips7', 'flips8', 'flips9']]
s6 = var6[['flips0', 'flips1', 'flips2', 'flips3', 'flips4', 'flips5', 'flips6', 'flips7', 'flips8', 'flips9']]
s8 = var8[['flips0', 'flips1', 'flips2', 'flips3', 'flips4', 'flips5', 'flips6', 'flips7', 'flips8', 'flips9']]
s10 = var10[['flips0', 'flips1', 'flips2', 'flips3', 'flips4', 'flips5', 'flips6', 'flips7', 'flips8', 'flips9']]

# %%
s2['Avg'] = (s2['flips0'] + s2['flips1'] + s2['flips2'] + s2['flips3'] + s2['flips4'] + s2['flips5'] + s2['flips6'] + s2['flips7'] + s2['flips8'] + s2['flips9']) / 10

s4['Avg'] = (s4['flips0'] + s4['flips1'] + s4['flips2'] + s4['flips3'] + s4['flips4'] + s4['flips5'] + s4['flips6'] + s4['flips7'] + s4['flips8'] + s4['flips9']) / 10

s6['Avg'] = (s6['flips0'] + s6['flips1'] + s6['flips2'] + s6['flips3'] + s6['flips4'] + s6['flips5'] + s6['flips6'] + s6['flips7'] + s6['flips8'] + s6['flips9']) / 10

s8['Avg'] = (s8['flips0'] + s8['flips1'] + s8['flips2'] + s8['flips3'] + s8['flips4'] + s8['flips5'] + s8['flips6'] + s8['flips7'] + s8['flips8'] + s8['flips9']) / 10

s10['Avg'] = (s10['flips0'] + s10['flips1'] + s10['flips2'] + s10['flips3'] + s10['flips4'] + s10['flips5'] + s10['flips6'] + s10['flips7'] + s10['flips8'] + s10['flips9']) / 10


line1 = s2['Avg']
line2 = s4['Avg']
line3 = s6['Avg']
line4 = s8['Avg']
line5 = s10['Avg']

plt.figure(figsize=(22.5,10))

plt.plot(s2['Avg'], label = 's = 2.0')

plt.plot(s4['Avg'], label = 's = 4.0')

plt.plot(s6['Avg'], label = 's = 6.0')

plt.plot(s8['Avg'], label = 's = 8.0')

plt.plot(s10['Avg'], label = 's = 10.0')

plt.legend(loc = 'upper right', fontsize=20)
plt.title('Average Number of TA Flips Across all 10 Classes for Different s Values', fontsize=20)
plt.xlabel('Inputs/Epochs', fontsize=15)
plt.ylabel('Average Number of TA flips across all 10 classes', fontsize=15)
plt.xlim([0, 100])

plt.yscale("log")
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# ...

# %%
plt.figure(figsize=(22.5,10))

plt.plot(var2[['flips0', 'flips1', 'flips2', 'flips3', 'flips4', 'flips5', 'flips6', 'flips7', 'flips8', 'flips9']])
plt.plot(var4[['flips0', 'flips1', 'flips2', 'flips3', 'flips4', 'flips5', 'flips6', 'flips7', 'flips8', 'flips9']])
plt.plot(var6[['flips0', 'flips1', 'flips2', 'flips3', 'flips4', 'flips5', 'flips6', 'flips7', 'flips8', 'flips9']])
plt.plot(var8[['flips0', 'flips1', 'flips2', 'flips3', 'flips4', 'flips5', 'flips6', 'flips7', 'flips8', 'flips9']])
plt.plot(var10[['flips0', 'flips1', 'flips2', 'flips3', 'flips4', 'flips5', 'flips6', 'flips7', 'flips8', 'flips9']])
'''
plt.plot(s2['Avg'], label = 's = 2.0')

plt.plot(s4['Avg'], label = 's = 4.0')

plt.plot(s6['Avg'], label = 's = 6.0')

plt.plot(s8['Avg'], label = 's = 8.0')

plt.plot(s10['Avg'], label = 's = 10.0')
'''
plt.legend(loc = 'upper right', fontsize=20)
plt.title('Average Rate of Change of TA Flips Across all 10 Classes for Different s Values', fontsize=20)
plt.xlabel('Steps', fontsize=15)
plt.ylabel('Average rate of change of TA flips across all 10 classes', fontsize=15)
plt.xlim([0, 100])

#plt.yscale("log")
# Out:
# No handles with labels found to put in legend.
# (0.0, 100.0)

# %%
# for s=2 sensitivity
s2['flip0_diff'] = s2['flips0'].diff()
s2['flip1_diff'] = s2['flips1'].diff()
s2['flip2_diff'] = s2['flips2'].diff()
s2['flip3_diff'] = s2['flips3'].diff()
s2['flip4_diff'] = s2['flips4'].diff()
s2['flip5_diff'] = s2['flips5'].diff()
s2['flip6_diff'] = s2['flips6'].diff()
s2['flip7_diff'] = s2['flips7'].diff()
s2['flip8_diff'] = s2['flips8'].diff()
s2['flip9_diff'] = s2['flips9'].diff()

s2['flip0_ROC'] = s2['flip0_diff']
s2['flip1_ROC'] = s2['flip1_diff']
s2['flip2_ROC'] = s2['flip2_diff']
s2['flip3_ROC'] = s2['flip3_diff']
s2['flip4_ROC'] = s2['flip4_diff']
s2['flip5_ROC'] = s2['flip5_diff']
s2['flip6_ROC'] = s2['flip6_diff']
s2['flip7_ROC'] = s2['flip7_diff']
s2['flip8_ROC'] = s2['flip8_diff']
s2['flip9_ROC'] = s2['flip9_diff']


# for s= 4 sensitivity
s4['flip0_diff'] = s4['flips0'].diff()
s4['flip1_diff'] = s4['flips1'].diff()
s4['flip2_diff'] = s4['flips2'].diff()
s4['flip3_diff'] = s4['flips3'].diff()
s4['flip4_diff'] = s4['flips4'].diff()
s4['flip5_diff'] = s4['flips5'].diff()
s4['flip6_diff'] = s4['flips6'].diff()
s4['flip7_diff'] = s4['flips7'].diff()
s4['flip8_diff'] = s4['flips8'].diff()
s4['flip9_diff'] = s4['flips9'].diff()

s4['flip0_ROC'] = s4['flip0_diff']
s4['flip1_ROC'] = s4['flip1_diff']
s4['flip2_ROC'] = s4['flip2_diff']
s4['flip3_ROC'] = s4['flip3_diff']
s4['flip4_ROC'] = s4['flip4_diff']
s4['flip5_ROC'] = s4['flip5_diff']
s4['flip6_ROC'] = s4['flip6_diff']
s4['flip7_ROC'] = s4['flip7_diff']
s4['flip8_ROC'] = s4['flip8_diff']
s4['flip9_ROC'] = s4['flip9_diff']

# for s= 6 sensitivity
s6['flip0_diff'] = s6['flips0'].diff()
s6['flip1_diff'] = s6['flips1'].diff()
s6['flip2_diff'] = s6['flips2'].diff()
s6['flip3_diff'] = s6['flips3'].diff()
s6['flip4_diff'] = s6['flips4'].diff()
s6['flip5_diff'] = s6['flips5'].diff()
s6['flip6_diff'] = s6['flips6'].diff()
s6['flip7_diff'] = s6['flips7'].diff()
s6['flip8_diff'] = s6['flips8'].diff()
s6['flip9_diff'] = s6['flips9'].diff()

s6['flip0_ROC'] = s6['flip0_diff']
s6['flip1_ROC'] = s6['flip1_diff']
s6['flip2_ROC'] = s6['flip2_diff']
s6['flip3_ROC'] = s6['flip3_diff']
s6['flip4_ROC'] = s6['flip4_diff']
s6['flip5_ROC'] = s6['flip5_diff']
s6['flip6_ROC'] = s6['flip6_diff']
s6['flip7_ROC'] = s6['flip7_diff']
s6['flip8_ROC'] = s6['flip8_diff']
s6['flip9_ROC'] = s6['flip9_diff']

# for s= 8 sensitivity
s8['flip0_diff'] = s8['flips0'].diff()
s8['flip1_diff'] = s8['flips1'].diff()
s8['flip2_diff'] = s8['flips2'].diff()
s8['flip3_diff'] = s8['flips3'].diff()
s8['flip4_diff'] = s8['flips4'].diff()
s8['flip5_diff'] = s8['flips5'].diff()
s8['flip6_diff'] = s8['flips6'].diff()
s8['flip7_diff'] = s8['flips7'].diff()
s8['flip8_diff'] = s8['flips8'].diff()
s8['flip9_diff'] = s8['flips9'].diff()

s8['flip0_ROC'] = s8['flip0_diff']
s8['flip1_ROC'] = s8['flip1_diff']
s8['flip2_ROC'] = s8['flip2_diff']
s8['flip3_ROC'] = s8['flip3_diff']
s8['flip4_ROC'] = s8['flip4_diff']
s8['flip5_ROC'] = s8['flip5_diff']
s8['flip6_ROC'] = s8['flip6_diff']
s8['flip7_ROC'] = s8['flip7_diff']
s8['flip8_ROC'] = s8['flip8_diff']
s8['flip9_ROC'] = s8['flip9_diff']

# for s= 10 sensitivity
s10['flip0_diff'] = s10['flips0'].diff()
s10['flip1_diff'] = s10['flips1'].diff()
s10['flip2_diff'] = s10['flips2'].diff()
s10['flip3_diff'] = s10['flips3'].diff()
s10['flip4_diff'] = s10['flips4'].diff()
s10['flip5_diff'] = s10['flips5'].diff()
s10['flip6_diff'] = s10['flips6'].diff()
s10['flip7_diff'] = s10['flips7'].diff()
s10['flip8_diff'] = s10['flips8'].diff()
s10['flip9_diff'] = s10['flips9'].diff()

s10['flip0_ROC'] = s10['flip0_diff']
s10['flip1_ROC'] = s10['flip1_diff']
s10['flip2_ROC'] = s10['flip2_diff']
s10['flip3_ROC'] = s10['flip3_diff']
s10['flip4_ROC'] = s10['flip4_diff']
s10['flip5_ROC'] = s10['flip5_diff']
s10['flip6_ROC'] = s10['flip6_diff']
s10['flip7_ROC'] = s10['flip7_diff']
s10['flip8_ROC'] = s10['flip8_diff']
s10['flip9_ROC'] = s10['flip9_diff']

# %%
import matplotlib.pyplot as plt

s2['AvgROC'] = (s2['flip0_ROC'] + s2['flip1_ROC'] + s2['flip2_ROC'] + s2['flip3_ROC'] + s2['flip4_ROC'] + s2['flip5_ROC'] + s2['flip6_ROC'] + s2['flip7_ROC'] + s2['flip8_ROC'] + s2['flip9_ROC']) / 10

s4['AvgROC'] = (s4['flip0_ROC'] + s4['flip1_ROC'] + s4['flip2_ROC'] + s4['flip3_ROC'] + s4['flip4_ROC'] + s4['flip5_ROC'] + s4['flip6_ROC'] + s4['flip7_ROC'] + s4['flip8_ROC'] + s4['flip9_ROC']) / 10

s6['AvgROC'] = (s6['flip0_ROC'] + s6['flip1_ROC'] + s6['flip2_ROC'] + s6['flip3_ROC'] + s6['flip4_ROC'] + s6['flip5_ROC'] + s6['flip6_ROC'] + s6['flip7_ROC'] + s6['flip8_ROC'] + s6['flip9_ROC']) / 10

s8['AvgROC'] = (s8['flip0_ROC'] + s8['flip1_ROC'] + s8['flip2_ROC'] + s8['flip3_ROC'] + s8['flip4_ROC'] + s8['flip5_ROC'] + s8['flip6_ROC'] + s8['flip7_ROC'] + s8['flip8_ROC'] + s8['flip9_ROC']) / 10

s10['AvgROC'] = (s10['flip0_ROC'] + s10['flip1_ROC'] + s10['flip2_ROC'] + s10['flip3_ROC'] + s10['flip4_ROC'] + s10['flip5_ROC'] + s10['flip6_ROC'] + s10['flip7_ROC'] + s10['flip8_ROC'] + s10['flip9_ROC']) / 10

line1 = s2['AvgROC']
line2 = s4['AvgROC']
line3 = s6['AvgROC']
line4 = s8['AvgROC']
line5 = s10['AvgROC']

plt.figure(figsize=(22.5,10))

plt.plot(s2['AvgROC'], label = 's = 2.0')

plt.plot(s4['AvgROC'], label = 's = 4.0')

plt.plot(s6['AvgROC'], label = 's = 6.0')

plt.plot(s8['AvgROC'], label = 's = 8.0')

plt.plot(s10['AvgROC'], label = 's = 10.0')

plt.legend(loc = 'upper right', fontsize=20)
plt.title('Average Rate of Change of TA Flips Across all 10 Classes for Different s Values', fontsize=20)
plt.xlabel('Steps', fontsize=15)
plt.ylabel('Average rate of change of TA flips across all 10 classes', fontsize=15)
plt.xlim([0, 100])

#plt.yscale("log")
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...
